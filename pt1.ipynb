# %%
# !pip install pandas
# !pip install matplotlib
# !pip install seaborn
# !pip install numpy
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from prep import df_white
from funcs import escala_dados

# %% [markdown]
# ## Média e desvio padrão de variaveis

# %%
vars=["fixed acidity","volatile acidity","citric acid","residual sugar","free sulfur dioxide","total sulfur dioxide","density","pH","sulphates","alcohol","opinion"]
for colus in df_white[vars].columns:
    print(f"{colus}: {np.mean(df_white[colus]): .2} +-{np.std(df_white[colus]): .2}")

# %% [markdown]
# ## Escolhendo variaveis

# %%
sns.pairplot(df_white[vars],hue="opinion",height=2)

# %%
df_white=df_white.drop(columns="type")
df_white_scaled,_,_=escala_dados(df_white,df_white)
colunas=list(df_white.columns)
df_white_scaled=pd.DataFrame(df_white_scaled,columns=colunas)
plt.subplots(figsize=(15, 8))
sns.heatmap(df_white_scaled.corr(), annot=True, cmap='coolwarm')
# Out:
# <Axes: >

# %% [markdown]
# ## Variaveis finais escolhidas

# %%
VARS=["fixed acidity","volatile acidity","residual sugar","total sulfur dioxide","density","alcohol"]
